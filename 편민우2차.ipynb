# %%
pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\jh060\anaconda3\lib\site-packages (2.0.3)
# Requirement already satisfied: numpy in c:\users\jh060\anaconda3\lib\site-packages (from xgboost) (1.24.3)
# Requirement already satisfied: scipy in c:\users\jh060\anaconda3\lib\site-packages (from xgboost) (1.10.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install mplfinance
# Out:
# Requirement already satisfied: mplfinance in c:\users\jh060\anaconda3\lib\site-packages (0.12.10b0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: matplotlib in c:\users\jh060\anaconda3\lib\site-packages (from mplfinance) (3.7.1)
# Requirement already satisfied: pandas in c:\users\jh060\anaconda3\lib\site-packages (from mplfinance) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jh060\anaconda3\lib\site-packages (from matplotlib->mplfinance) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\jh060\anaconda3\lib\site-packages (from matplotlib->mplfinance) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jh060\anaconda3\lib\site-packages (from matplotlib->mplfinance) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\jh060\anaconda3\lib\site-packages (from matplotlib->mplfinance) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\jh060\anaconda3\lib\site-packages (from matplotlib->mplfinance) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\jh060\anaconda3\lib\site-packages (from matplotlib->mplfinance) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\jh060\anaconda3\lib\site-packages (from matplotlib->mplfinance) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\jh060\anaconda3\lib\site-packages (from matplotlib->mplfinance) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jh060\anaconda3\lib\site-packages (from matplotlib->mplfinance) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jh060\anaconda3\lib\site-packages (from pandas->mplfinance) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\users\jh060\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->mplfinance) (1.16.0)

# %% [markdown]
# #### 데이터 사전
#
# - Open - 봉의 기간 중 처음 거래 가격
# - High - 봉의 기간 중 가장 높은 가격
# - Low - 봉의 기간 중 가장 낮은 가격
# - Close - 봉의 기간 중 마지막 거래 가격
# - Adj - 봉의 기간 중 마지막 거래 가격 (이벤트 반영)
# - Volume - 봉 하나의 거래량

# %%
import pandas as pd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import mplfinance as mpf
from xgboost import XGBRegressor

# %%
# 일봉 조회
df = pd.read_csv('BTC-USD.csv')

# 'Date' 열을 datetime 형태로 변환
df['Date'] = pd.to_datetime(df['Date'])

# 'Date' 열을 인덱스로 설정
df.set_index('Date', inplace=True)

print(df)
# Out:
#                     Open          High           Low         Close  \
# Date
# 2014-09-17    465.864014    468.174011    452.421997    457.334015
# 2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2014-09-19    424.102997    427.834991    384.532013    394.795990
# 2014-09-20    394.673004    423.295990    389.882996    408.903992
# 2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...                  ...           ...           ...           ...
# 2023-07-15  30331.783203  30407.781250  30263.462891  30295.806641
# 2023-07-16  30297.472656  30437.560547  30089.669922  30249.132813
# 2023-07-17  30249.626953  30336.400391  29685.783203  30145.888672
# 2023-07-18  30147.070313  30233.656250  29556.427734  29856.562500
# 2023-07-20  29919.064453  30224.115234  29918.281250  30189.902344
#
#                Adj Close       Volume
# Date
# 2014-09-17    457.334015     21056800
# 2014-09-18    424.440002     34483200
# 2014-09-19    394.795990     37919700
# 2014-09-20    408.903992     36863600
# 2014-09-21    398.821014     26580100
# ...                  ...          ...
# 2023-07-15  30295.806641   8011667756
# 2023-07-16  30249.132813   8516564470
# 2023-07-17  30145.888672  13240156074
# 2023-07-18  29856.562500  13138897269
# 2023-07-20  30189.902344  11906640896
#
# [3228 rows x 6 columns]

# %%
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-09-17  465.864014  468.174011  452.421997  457.334015  457.334015
# 2014-09-18  456.859985  456.859985  413.104004  424.440002  424.440002
# 2014-09-19  424.102997  427.834991  384.532013  394.795990  394.795990
# 2014-09-20  394.673004  423.295990  389.882996  408.903992  408.903992
# 2014-09-21  408.084991  412.425995  393.181000  398.821014  398.821014
#
#               Volume
# Date
# 2014-09-17  21056800
# 2014-09-18  34483200
# 2014-09-19  37919700
# 2014-09-20  36863600
# 2014-09-21  26580100

# %%
mpf.plot(df, type='line')

# %%
mpf.plot(df, volume = True, type='line')

# %% [markdown]
# - 2021년에 거래량 및 가격이 압도적으로 높음

# %%
Op=np.array(df["Open"])
Hi=np.array(df["High"])
Lo=np.array(df["Low"])
AC=np.array(df["Adj Close"])
V=np.array(df["Volume"])

# %% [markdown]
# - 정확한 예측을 위해 종가가 아닌 수정 종가를 반영

# %%
input=np.column_stack((Op,Hi,Lo,V))
output=AC

# %%
# input 중 op,hi,lo는 가격을 의미하고 v는 거래량을 의미해 다른 사이즈를 맞추는 작업
from sklearn.preprocessing import StandardScaler
SS = StandardScaler()
input_scaled=SS.fit_transform(input)

# %%
from sklearn.model_selection import train_test_split
train_input,test_input,train_output,test_output=train_test_split(input_scaled,output)

# %%
from xgboost import XGBRegressor, plot_importance

XGBR=XGBRegressor(max_depth=3, reg_alpha=0.1)
XGBR.fit(train_input,train_output)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
plot_importance(XGBR).set_yticklabels(['Open','High','Low','Volume'])
# Out:
# [Text(0, 0, 'Open'),
#  Text(0, 1, 'High'),
#  Text(0, 2, 'Low'),
#  Text(0, 3, 'Volume')]

# %%
plt.plot(XGBR.predict(test_input),'w')
plt.plot(test_output,'b')

# %% [markdown]
# - 파란색 그래프가 예측값
# - 흰색이 실제값

# %%
XGBR.score(test_input,test_output)
# 모델평가 99.9점
# Out:
# 0.9990629163887901
